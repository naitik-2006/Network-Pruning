# %%
# -*- coding: utf-8 -*-
"""
Created on Mon May 27 16:57:52 2024

@author: Naitik
"""
import torch # type: ignore
import json

from pycocoevalcap.cider import cider
import pycocoevalcap.meteor as meteor
from pycocoevalcap.rouge import rouge
from pycocoevalcap.bleu import bleu
from get_loader_test import get_loader
import torchvision.transforms as transforms # type: ignore
from  New_Pruned_Model import EncodertoDecoder as pruned_model
from nltk.translate.meteor_score import meteor_score # type: ignore
from nltk.tokenize import word_tokenize # type: ignore
from torch.utils.tensorboard import SummaryWriter # type: ignore

# %%
import sys
import os

gl = sys.stdout

# Suppress print statements
def suppress_stdout():
    sys.stdout = open(os.devnull, 'w')

# Restore print statements
def restore_stdout():
    sys.stdout = gl

# %%
def caption_generate_2(model,dataset,image,device,max_length = 50):
    outputs=[dataset.vocab.stoi["<SOS>"]]
    for i in range(max_length):
        trg_tensor =torch.LongTensor(outputs).unsqueeze(1).to(device)
        print(trg_tensor.shape)
        image = image.to(device)
        
        
        with torch.no_grad():
            output = model(image,trg_tensor)
                
        print("From here" , output.shape)
            
        best_guess = output.argmax(2)[-1, :].item()
        outputs.append(best_guess)
        
        if best_guess == dataset.vocab.stoi["<EOS>"]:
            break
    caption = [dataset.vocab.itos[idx] for idx in outputs]
    
    return caption[1:]

def caption_generate(model,dataset,image,device,max_length = 50):
    outputs=[dataset.vocab.stoi["<SOS>"]]
    for i in range(max_length):
        trg_tensor =torch.LongTensor(outputs).unsqueeze(1).to(device)
        print(trg_tensor.shape)
        image = image.to(device)
        
        
        with torch.no_grad():
            output, _ = model(image,trg_tensor)
                
        print("From here" , output.shape)
            
        best_guess = output.argmax(2)[-1, :].item()
        outputs.append(best_guess)
        
        if best_guess == dataset.vocab.stoi["<EOS>"]:
            break
    caption = [dataset.vocab.itos[idx] for idx in outputs]
    
    return caption[1:]

# %%
import shutil

# %%
import os
import json
import torch
import torchvision.utils as vutils

def run_validation(pruned_model, unpruned_model, validation_dataloader, validation_dataset, max_len, device):
    pruned_model.eval()
    unpruned_model.eval()
    
    results_dict = {}

    # Create logs directory
    logs_dir = "rscid_logs"
    os.makedirs(logs_dir, exist_ok=True)

    with torch.no_grad():
        for idx, (image, caption, image_name) in enumerate(validation_dataloader):
            image = image.to(device)

            # Ensure batch size is 1
            assert image.size(0) == 1, "Batch size must be 1 for validation"

            print(f"Processing Image {idx + 1}: {image_name[0]}")

            # Generate captions for both models
            suppress_stdout()  # Disable print
            pruned_out = caption_generate(pruned_model, validation_dataset, image, device, max_len)
            unpruned_out = caption_generate_2(unpruned_model, validation_dataset, image, device, max_len)
            restore_stdout()

            # Convert target captions to text
            target_text = caption.detach().cpu().numpy().tolist()
            target_text_flat = [token for sublist in target_text for token in sublist]

            # Convert predicted tokens to text
            def tokens_to_text(tokens):
                text = ""
                for token in tokens:
                    if token == '<EOS>':
                        break
                    text += token + " "
                return text.strip()

            expected_text = " ".join(validation_dataset.vocab.itos[i] for i in target_text_flat if validation_dataset.vocab.itos[i] != '<EOS>')
            pruned_text = tokens_to_text(pruned_out)
            unpruned_text = tokens_to_text(unpruned_out)

            # Store results in dictionary
            image_name_str = image_name[0]  # Assuming image_name is a list with one string
            if image_name_str not in results_dict:
                results_dict[image_name_str] = []
            
            results_dict[image_name_str].append({
                "Expected": expected_text,
                "Pruned_Predicted": pruned_text,
                "Unpruned_Predicted": unpruned_text
            })
            
            print({
                "Expected": expected_text,
                "Pruned_Predicted": pruned_text,
                "Unpruned_Predicted": unpruned_text
            })

            # Create image folder inside logs
            image_folder = os.path.join(logs_dir, "".join(image_name_str.split(".")[:-1]))
            os.makedirs(image_folder, exist_ok=True)

            # Save image inside the corresponding folder
            image_path = os.path.join(image_folder, "image.png")
            shutil.copy(os.path.join('D:\ML\Korea\Jishu\Jishu\\rsicd\images\\', image_name_str), image_path)

            # Save results in text format for easy access
            with open(os.path.join(image_folder, "captions.json"), "w") as f:
                json.dump(results_dict[image_name_str], f, indent=4)

            print(f"✅ Saved results for {image_name_str}")

    # Save full results dictionary as JSON
    with open(os.path.join(logs_dir, "results.json"), "w") as json_file:
        json.dump(results_dict, json_file, indent=4)

    print("✅ All results saved successfully in logs folder!")
# Out:
# <>:71: SyntaxWarning: invalid escape sequence '\M'
# <>:71: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\codes\AppData\Local\Temp\ipykernel_7780\3418625703.py:71: SyntaxWarning: invalid escape sequence '\M'
#   shutil.copy(os.path.join('D:\ML\Korea\Jishu\Jishu\\rsicd\images\\', image_name_str), image_path)

# %%
print("Hello")
# Out:
# Hello

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
transform = transforms.Compose([transforms.Resize((256,256)),
                            transforms.ToTensor(),
                            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

images_path , caption_path = r"D:\ML\Korea\Jishu\Jishu\rsicd\images" , r"D:\ML\Korea\Jishu\Jishu\rsicd\captions.csv"
validation_dataloader , validation_dataset = get_loader(images_path,caption_path ,transform,num_workers=4 , train = False)
trg_vocab_size = len(validation_dataset.vocab)
max_len = 50

# %% [markdown]
# # Our Approach

# %%
pruned_model = torch.load('D:\ML\Korea\Jishu\Jishu\Final_Docs\Complete_Model_Pruning\model_final_4_2_T.pth')
pruned_model = pruned_model.to(device)

# Initialize the tensorboard
logs_dir = "logs"
writer = SummaryWriter(logs_dir)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\codes\AppData\Local\Temp\ipykernel_7780\2156390483.py:1: SyntaxWarning: invalid escape sequence '\M'
#   pruned_model = torch.load('D:\ML\Korea\Jishu\Jishu\Final_Docs\Complete_Model_Pruning\model_final_4_2_T.pth')
# C:\Users\codes\AppData\Local\Temp\ipykernel_7780\2156390483.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   pruned_model = torch.load('D:\ML\Korea\Jishu\Jishu\Final_Docs\Complete_Model_Pruning\model_final_4_2_T.pth')

# %% [markdown]
# # Unpruned Model

# %%
import torch
import sys
sys.path.append("../Original_Image_Captioning_Model")  # Add the parent folder
from Model import *  # Now import works

unpruned_model = torch.load('D:\ML\Korea\Jishu\Jishu\Final_Docs\Original_Image_Captioning_Model\original_unpruned_model.pth')
unpruned_model = unpruned_model.to(device)
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\M'
# <>:6: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\codes\AppData\Local\Temp\ipykernel_7780\3254119190.py:6: SyntaxWarning: invalid escape sequence '\M'
#   unpruned_model = torch.load('D:\ML\Korea\Jishu\Jishu\Final_Docs\Original_Image_Captioning_Model\original_unpruned_model.pth')
# C:\Users\codes\AppData\Local\Temp\ipykernel_7780\3254119190.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   unpruned_model = torch.load('D:\ML\Korea\Jishu\Jishu\Final_Docs\Original_Image_Captioning_Model\original_unpruned_model.pth')

# %%
print("Hello")
# Out:
# Hello

# %%
run_validation(pruned_model,unpruned_model, validation_dataloader, validation_dataset, max_len, device)
# Out:
# Processing Image 1: resort_145.jpg
# c:\Users\codes\anaconda3\envs\ml\Lib\site-packages\torch\nn\functional.py:5560: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:555.)
#   attn_output = scaled_dot_product_attention(q, k, v, attn_mask, dropout_p, is_causal)
# c:\Users\codes\anaconda3\envs\ml\Lib\site-packages\torch\nn\functional.py:5193: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# {'Expected': '<SOS> several buildings and many green trees are near a river .', 'Pruned_Predicted': 'several buildings with swimming pool are semi - surrounded by a piece of water .', 'Unpruned_Predicted': 'many buildings and green trees are in a school .'}
# ✅ Saved results for resort_145.jpg
# Processing Image 2: mediumresidential_259.jpg
# {'Expected': '<SOS> some buildings and many green trees are located in an average residential area .', 'Pruned_Predicted': 'some buildings and many green trees are in a medium residential area .', 'Unpruned_Predicted': 'many green trees are around a building with a swimming pool .'}
# ✅ Saved results for mediumresidential_259.jpg
# Processing Image 3: playground_106.jpg
# {'Expected': '<SOS> a football field is close to a road and several cars .', 'Pruned_Predicted': 'a football field is near a road with cars .', 'Unpruned_Predicted': 'a football field is near several buildings and some green trees .'}
# ✅ Saved results for playground_106.jpg
# Processing Image 4: desert_8.jpg
# {'Expected': '<SOS> desolate in the desert .', 'Pruned_Predicted': "it 's a piece of yellow bare land .", 'Unpruned_Predicted': "it 's a piece of yellow desert ."}
# ✅ Saved results for desert_8.jpg
# Processing Image 5: mountain_330.jpg
# {'Expected': '<SOS> some part of the mountain is covered by vegetations while others are bare .', 'Pruned_Predicted': "it 's a piece of green mountain .", 'Unpruned_Predicted': 'many green trees are in two sides of a curved river .'}
# ✅ Saved results for mountain_330.jpg
# Processing Image 6: viaduct_275.jpg
# {'Expected': '<SOS> many buildings and agricultural land are on two sides of a viaduct with four circles around the green trees .', 'Pruned_Predicted': 'many green trees and some buildings are near a viaduct .', 'Unpruned_Predicted': 'many buildings and some green trees are in a school .'}
# ✅ Saved results for viaduct_275.jpg
# Processing Image 7: farmland_313.jpg
# {'Expected': '<SOS> many green farmlands are in two sides of a small river .', 'Pruned_Predicted': 'a football field is near a road with several cars .', 'Unpruned_Predicted': 'many green trees are in two sides of a curved river .'}
# ✅ Saved results for farmland_313.jpg
# Processing Image 8: railwaystation_202.jpg
# {'Expected': '<SOS> several buildings are located on two sides of a train station .', 'Pruned_Predicted': 'many buildings are located on two sides of a train station .', 'Unpruned_Predicted': 'many buildings and some bareland are in an industrial area .'}
# ✅ Saved results for railwaystation_202.jpg
# Processing Image 9: bareland_72.jpg
# {'Expected': "<SOS> it 's a big piece of naked dirt .", 'Pruned_Predicted': "it 's a piece of yellow bare land .", 'Unpruned_Predicted': "it 's a piece of yellow desert ."}
# ✅ Saved results for bareland_72.jpg
# Processing Image 10: denseresidential_355.jpg
# {'Expected': '<SOS> the residential buildings on both sides of the road are neatly arranged .', 'Pruned_Predicted': 'many buildings and green trees are in a dense residential area .', 'Unpruned_Predicted': 'many buildings and some green trees are in a dense residential area .'}
# ✅ Saved results for denseresidential_355.jpg
# Processing Image 11: port_346.jpg
# {'Expected': '<SOS> many trucks are on the road along the coast of the harbour .', 'Pruned_Predicted': 'many boats are in a port near a dock .', 'Unpruned_Predicted': 'many boats are ordered in a port near several green trees .'}
# ✅ Saved results for port_346.jpg
# Processing Image 12: 00307.jpg
# {'Expected': '<SOS> two courts which are surrounded by buildings and located at <UNK> can be <UNK> seen .', 'Pruned_Predicted': 'a playground with basketball fields next to it is surrounded by many buildings .', 'Unpruned_Predicted': 'many buildings and green trees are in a school with a playground and several parking lots .'}
# ✅ Saved results for 00307.jpg
# Processing Image 13: viaduct_256.jpg
# {'Expected': '<SOS> many cars are in a busy viaduct near some green trees and several buildings .', 'Pruned_Predicted': 'a parking lot and many cars are near a viaduct .', 'Unpruned_Predicted': 'many buildings and some green trees are in a commercial area .'}
# ✅ Saved results for viaduct_256.jpg
# Processing Image 14: forest_37.jpg
# {'Expected': '<SOS> there was a thick forest beside the bare land .', 'Pruned_Predicted': 'many green trees are in a forest .', 'Unpruned_Predicted': 'many green trees are in a forest .'}
# ✅ Saved results for forest_37.jpg
# Processing Image 15: square_211.jpg
# {'Expected': '<SOS> there are sparse trees on the oval shaped square with white paths .', 'Pruned_Predicted': 'many green trees are in a square .', 'Unpruned_Predicted': 'many buildings and some green trees are in an industrial area .'}
# ✅ Saved results for square_211.jpg
# Processing Image 16: pond_348.jpg
# {'Expected': '<SOS> a rectangular lake is separated by two small rectangles .', 'Pruned_Predicted': 'a road is between a football playground and villas .', 'Unpruned_Predicted': 'many boats are in a port near many buildings .'}
# ✅ Saved results for pond_348.jpg
# Processing Image 17: pond_395.jpg
# {'Expected': "<SOS> there 's a pond in the bare land .", 'Pruned_Predicted': 'some green trees and bare land are around an irregular pond .', 'Unpruned_Predicted': 'many green trees are around an irregular pond .'}
# ✅ Saved results for pond_395.jpg
# Processing Image 18: storagetanks_17.jpg
# {'Expected': '<SOS> many storage tanks in a factory are near several railways .', 'Pruned_Predicted': 'many storage tanks are in a factory .', 'Unpruned_Predicted': 'many planes are parked near several terminals in an airport with several parking lots .'}
# ✅ Saved results for storagetanks_17.jpg
# Processing Image 19: denseresidential_65.jpg
# {'Expected': '<SOS> many green trees and buildings are in a dense residential area .', 'Pruned_Predicted': 'many green trees and buildings are in a park .', 'Unpruned_Predicted': 'many buildings and some green trees are in a commercial area .'}
# ✅ Saved results for denseresidential_65.jpg
# Processing Image 20: farmland_21.jpg
# {'Expected': '<SOS> many pieces of green farmlands are together .', 'Pruned_Predicted': 'many pieces of farmlands are together .', 'Unpruned_Predicted': 'many pieces of agricultural land are together .'}
# ✅ Saved results for farmland_21.jpg
# Processing Image 21: beach_242.jpg
# {'Expected': '<SOS> this beach sits alongside the road .', 'Pruned_Predicted': 'a yellow ribbon beach is between green ocean and black rocks .', 'Unpruned_Predicted': 'yellow beach is near a piece of green ocean .'}
# ✅ Saved results for beach_242.jpg
# Processing Image 22: airport_153.jpg
# {'Expected': '<SOS> many aircraft are located in an airport near many buildings .', 'Pruned_Predicted': 'many buildings are located on two sides of a train station .', 'Unpruned_Predicted': 'many buildings and some bareland are in an industrial area .'}
# ✅ Saved results for airport_153.jpg
# Processing Image 23: center_52.jpg
# {'Expected': '<SOS> a quadrangle striped blue green building is surrounded by rows of trees   lawns roads and other buildings .', 'Pruned_Predicted': 'a circle building is surrounded by some green trees .', 'Unpruned_Predicted': 'many green trees and a pond are in a park .'}
# ✅ Saved results for center_52.jpg
# Processing Image 24: industrial_70.jpg
# {'Expected': '<SOS> many buildings are located in an industrial area .', 'Pruned_Predicted': 'many industrial buildings are in an industrial area .', 'Unpruned_Predicted': 'many buildings and some green trees are in an industrial area .'}
# ✅ Saved results for industrial_70.jpg
# Processing Image 25: parking_338.jpg
# {'Expected': '<SOS> some cars are in a parking lot with many empty parking spaces near different buildings .', 'Pruned_Predicted': 'many cars are in a parking lot near a building and several green trees .', 'Unpruned_Predicted': 'many cars are parked in a parking lot near several buildings .'}
# ✅ Saved results for parking_338.jpg
# Processing Image 26: airport_9.jpg
# {'Expected': '<SOS> some planes are parked near a building in an airport .', 'Pruned_Predicted': 'a white plane is near a terminal in an airport .', 'Unpruned_Predicted': 'white waves in an ocean are near a beach .'}
# ✅ Saved results for airport_9.jpg
# Processing Image 27: sparseresidential_297.jpg
# {'Expected': '<SOS> a white car is parked in front of the house .', 'Pruned_Predicted': 'a building is surrounded by many green trees .', 'Unpruned_Predicted': 'many green trees are around a building with a swimming pool .'}
# ✅ Saved results for sparseresidential_297.jpg
# Processing Image 28: airport_225.jpg
# {'Expected': '<SOS> rectangle airport and <UNK> flight strips .', 'Pruned_Predicted': 'many planes are parked near several terminals in an airport with several parking lots .', 'Unpruned_Predicted': 'many buildings and some bareland are in an industrial area .'}
# ✅ Saved results for airport_225.jpg
# Processing Image 29: square_15.jpg
# {'Expected': '<SOS> many green trees are ordered in one square .', 'Pruned_Predicted': 'many green trees and some buildings are in a medium residential area .', 'Unpruned_Predicted': 'many green trees are around a building with a swimming pool .'}
# ✅ Saved results for square_15.jpg
# Processing Image 30: bareland_187.jpg
# {'Expected': "<SOS> it 's the mountain region and the lakes .", 'Pruned_Predicted': 'many buildings are near a large piece of bare land .', 'Unpruned_Predicted': 'many buildings and some bareland are in an industrial area .'}
# ✅ Saved results for bareland_187.jpg
# Processing Image 31: viaduct_271.jpg
# {'Expected': '<SOS> many green trees are near a viaduct with two cars .', 'Pruned_Predicted': 'many green trees and some buildings are near a viaduct .', 'Unpruned_Predicted': 'many buildings and some green trees are in a school .'}
# ✅ Saved results for viaduct_271.jpg
# Processing Image 32: port_134.jpg
# {'Expected': '<SOS> some boats are in a port near many green buildings and trees .', 'Pruned_Predicted': 'many boats are in a port near some buildings and green trees .', 'Unpruned_Predicted': 'many buildings are in an industrial area .'}
# ✅ Saved results for port_134.jpg
# Processing Image 33: bareland_171.jpg
# {'Expected': '<SOS> a road with some green trees is close to a bare piece of land .', 'Pruned_Predicted': 'several green trees are near a bare piece of land .', 'Unpruned_Predicted': "it 's a piece of irregular khaki nueland ."}
# ✅ Saved results for bareland_171.jpg
# Processing Image 34: industrial_346.jpg
# {'Expected': '<SOS> on both sides of the road is a huge industrial area .', 'Pruned_Predicted': 'many buildings and some green trees are in an industrial area .', 'Unpruned_Predicted': 'many buildings and green trees are in a dense residential area .'}
# ✅ Saved results for industrial_346.jpg
# Processing Image 35: pond_21.jpg
# {'Expected': '<SOS> several ponds are surrounded by bare and green trees .', 'Pruned_Predicted': 'many green trees and some buildings are around a large park with a pond .', 'Unpruned_Predicted': 'a playground is surrounded by some green trees and many buildings .'}
# ✅ Saved results for pond_21.jpg
# Processing Image 36: river_236.jpg
# {'Expected': '<SOS> trees are cut down and several houses are build on the bank of this yellow river .', 'Pruned_Predicted': 'many green trees are in two sides of a curved yellow river .', 'Unpruned_Predicted': 'many green trees are in two sides of a curved yellow river .'}
# ✅ Saved results for river_236.jpg
# Processing Image 37: meadow_275.jpg
# {'Expected': '<SOS> several green trees are scattered sparsely in a piece of green meadow .', 'Pruned_Predicted': 'a road is near a piece of green meadow .', 'Unpruned_Predicted': "it 's a piece of green meadow ."}
# ✅ Saved results for meadow_275.jpg
# Processing Image 38: bridge_128.jpg
# {'Expected': '<SOS> a bridge is on a river with some buildings in two sides of it .', 'Pruned_Predicted': 'a bridge is on a river with some green trees and several buildings on two sides of it .', 'Unpruned_Predicted': 'many planes are parked near several terminals in an airport with several parking lots .'}
# ✅ Saved results for bridge_128.jpg
# Processing Image 39: storagetanks_56.jpg
# {'Expected': '<SOS> several storage tanks stands here connected with pipes at the coner of the roads .', 'Pruned_Predicted': 'some storage tanks are near a road .', 'Unpruned_Predicted': 'many storage tanks are near a river .'}
# ✅ Saved results for storagetanks_56.jpg
# Processing Image 40: bareland_56.jpg
# {'Expected': '<SOS> it is a piece of gray green bareland .', 'Pruned_Predicted': "it 's a piece of yellow bare land .", 'Unpruned_Predicted': "it 's a piece of irregular khaki nueland ."}
# ✅ Saved results for bareland_56.jpg
# Processing Image 41: railwaystation_15.jpg
# {'Expected': '<SOS> many green buildings and plants are located on two sides of a train station .', 'Pruned_Predicted': 'many buildings with parking lots and some green trees are located on both sides of a train station .', 'Unpruned_Predicted': 'many green trees and several buildings with swimming pools are close to a beach in a resort .'}
# ✅ Saved results for railwaystation_15.jpg
# Processing Image 42: industrial_386.jpg
# {'Expected': '<SOS> there is a factory with white trucks and blue containers beside two roads .', 'Pruned_Predicted': 'a large building is near a river .', 'Unpruned_Predicted': 'many cars are parked in a parking lot with several green trees .'}
# ✅ Saved results for industrial_386.jpg
# Processing Image 43: storagetanks_172.jpg
# {'Expected': '<SOS> seven white storage tanks are close to several pieces of meadows .', 'Pruned_Predicted': 'many storage tanks are near a large piece of green meadow .', 'Unpruned_Predicted': 'many planes are parked near several terminals in an airport with several parking lots .'}
# ✅ Saved results for storagetanks_172.jpg
# Processing Image 44: viaduct_220.jpg
# {'Expected': '<SOS> several buildings and many green plants are near a viaduct .', 'Pruned_Predicted': 'many green trees are near a viaduct .', 'Unpruned_Predicted': 'many buildings and some green trees are in a commercial area .'}
# ✅ Saved results for viaduct_220.jpg
# Processing Image 45: denseresidential_68.jpg
# {'Expected': '<SOS> many buildings are located in a dense residential area .', 'Pruned_Predicted': 'many buildings are in a dense residential area .', 'Unpruned_Predicted': 'many buildings and green trees are in a dense residential area .'}
# ✅ Saved results for denseresidential_68.jpg
# Processing Image 46: mediumresidential_21.jpg
# {'Expected': '<SOS> some red buildings and many green trees are in a medium residential area .', 'Pruned_Predicted': 'some red buildings and green trees are in a medium residential area .', 'Unpruned_Predicted': 'a large number of cars parked near the airport plains .'}
# ✅ Saved results for mediumresidential_21.jpg
# Processing Image 47: square_47.jpg
# {'Expected': '<SOS> an x path separates the <UNK> in the square which is surrounded on three sides by the road .', 'Pruned_Predicted': 'some green trees are around a square circle .', 'Unpruned_Predicted': 'many green trees are around a square with green trees .'}
# ✅ Saved results for square_47.jpg
# Processing Image 48: resort_253.jpg
# {'Expected': '<SOS> many green trees and some buildings are in a seaside resort with a pond .', 'Pruned_Predicted': 'many green trees and some buildings are in two sides of a river with a small bridge .', 'Unpruned_Predicted': 'many buildings and some green trees are in a commercial area .'}
# ✅ Saved results for resort_253.jpg
# Processing Image 49: square_312.jpg
# {'Expected': '<SOS> on both sides of the square are houses with brown ceilings .', 'Pruned_Predicted': 'a large number of green plants are planted around the building .', 'Unpruned_Predicted': 'many buildings and some green trees are in a dense residential area .'}
# ✅ Saved results for square_312.jpg
# Processing Image 50: stadium_216.jpg
# {'Expected': '<SOS> some buildings are near a rectangle white stadium .', 'Pruned_Predicted': 'a parking lot and some green trees are near a stadium .', 'Unpruned_Predicted': 'a large white building is near a road with several cars in an industrial area .'}
# ✅ Saved results for stadium_216.jpg
# Processing Image 51: farmland_255.jpg
# {'Expected': '<SOS> a small straight river is in many pieces of brown farmlands .', 'Pruned_Predicted': 'many pieces of farmlands are orderly together .', 'Unpruned_Predicted': 'many green trees are near a viaduct with some cars .'}
# ✅ Saved results for farmland_255.jpg
# Processing Image 52: parking_357.jpg
# {'Expected': '<SOS> some trees were planted around the parking lot .', 'Pruned_Predicted': 'many cars are in a parking lot near a large building and a road .', 'Unpruned_Predicted': 'many cars are parked in a parking lot with several small trees .'}
# ✅ Saved results for parking_357.jpg
# Processing Image 53: airport_275.jpg
# {'Expected': '<SOS> several planes are in an airport with a parking lot .', 'Pruned_Predicted': 'many planes are parked in an airport .', 'Unpruned_Predicted': 'many planes are parked near a large building in an airport .'}
# ✅ Saved results for airport_275.jpg
# Processing Image 54: resort_66.jpg
# {'Expected': '<SOS> there is a zigzag building with a swimming pool in the resort   next to which is a parking lot and two tennis fields .', 'Pruned_Predicted': 'several buildings with swimming pool and some green trees are in a resort .', 'Unpruned_Predicted': 'many buildings and some green trees are in a resort .'}
# ✅ Saved results for resort_66.jpg
# Processing Image 55: bareland_215.jpg
# {'Expected': '<SOS> some green plants are close to a piece of khaki bareland .', 'Pruned_Predicted': "it 's a piece of irregular caki stripping .", 'Unpruned_Predicted': "it 's a piece of yellow desert ."}
# ✅ Saved results for bareland_215.jpg
# Processing Image 56: baseballfield_67.jpg
# {'Expected': '<SOS> four baseball field in every quarter of a circle lawn .', 'Pruned_Predicted': 'four baseball fields are surrounded by many green trees and buildings .', 'Unpruned_Predicted': 'a baseball field is near several green trees and a building .'}
# ✅ Saved results for baseballfield_67.jpg
# Processing Image 57: 00174.jpg
# {'Expected': '<SOS> many buildings and some green plants are around a playground .', 'Pruned_Predicted': 'a playground with basketball fields next to it is surrounded by many buildings .', 'Unpruned_Predicted': 'many buildings and some green trees are in a school .'}
# ✅ Saved results for 00174.jpg
# Processing Image 58: meadow_179.jpg
# {'Expected': '<SOS> a white rectangular <UNK> can be seen in this green meadow .', 'Pruned_Predicted': 'a row of green trees is near a piece of green meadow .', 'Unpruned_Predicted': 'a road is near a piece of green meadow .'}
# ✅ Saved results for meadow_179.jpg
# Processing Image 59: bareland_242.jpg
# {'Expected': '<SOS> a piece of land <UNK> .', 'Pruned_Predicted': "it 's a piece of bare land .", 'Unpruned_Predicted': "it 's a piece of yellow stripe ."}
# ✅ Saved results for bareland_242.jpg
# Processing Image 60: industrial_346.jpg
# {'Expected': '<SOS> a large white building was built in the industrial area .', 'Pruned_Predicted': 'many buildings and some green trees are in an industrial area .', 'Unpruned_Predicted': 'many buildings and green trees are in a dense residential area .'}
# ✅ Saved results for industrial_346.jpg
# Processing Image 61: river_282.jpg
# {'Expected': '<SOS> some green trees are found on both sides of a curved yellow river .', 'Pruned_Predicted': 'the river is curved and lush and the trees are flourishing .', 'Unpruned_Predicted': 'many green trees are around a square with green trees .'}
# ✅ Saved results for river_282.jpg
# Processing Image 62: parking_264.jpg
# {'Expected': '<SOS> many cars are parked in a small parking lot near several buildings and green trees .', 'Pruned_Predicted': 'many cars are parked in a parking lot near a building and several green trees .', 'Unpruned_Predicted': 'many cars are parked in a parking lot with several small trees .'}
# ✅ Saved results for parking_264.jpg
# Processing Image 63: beach_161.jpg
# {'Expected': '<SOS> two rows of waves in the green ocean are located near a yellow beach .', 'Pruned_Predicted': 'a line of white waves are between green ocean and yellow beach .', 'Unpruned_Predicted': 'a large white building is near a road with some cars parked at the gate .'}
# ✅ Saved results for beach_161.jpg
# Processing Image 64: bridge_43.jpg
# {'Expected': '<SOS> many ships <UNK> on the river .', 'Pruned_Predicted': 'a bridge is on a yellow undulation .', 'Unpruned_Predicted': 'a large number of cars parked near the airport plains .'}
# ✅ Saved results for bridge_43.jpg
# Processing Image 65: bridge_106.jpg
# {'Expected': '<SOS> a bridge is on a river with many buildings on two sides .', 'Pruned_Predicted': 'a bridge is on a river with some buildings on two sides of it .', 'Unpruned_Predicted': 'many buildings and some green trees are in a commercial area .'}
# ✅ Saved results for bridge_106.jpg
# Processing Image 66: viaduct_418.jpg
# {'Expected': '<SOS> some tall trees were planted around the overpass .', 'Pruned_Predicted': 'many buildings and some green trees are near a viaduct .', 'Unpruned_Predicted': 'many buildings and green trees are in a dense residential area .'}
# ✅ Saved results for viaduct_418.jpg
# Processing Image 67: beach_341.jpg
# {'Expected': '<SOS> the water to the beach against big white waves .', 'Pruned_Predicted': 'yellow beach is near a piece of green ocean .', 'Unpruned_Predicted': 'many green trees are in two sides of a curved yellow river .'}
# ✅ Saved results for beach_341.jpg
# Processing Image 68: 00081.jpg
# {'Expected': '<SOS> a playground semisurrounded by many buildings and green trees is next to two roads .', 'Pruned_Predicted': 'a playground with a basketball field next to it is surrounded by many buildings .', 'Unpruned_Predicted': 'many buildings and some bareland are in an industrial area .'}
# ✅ Saved results for 00081.jpg
# Processing Image 69: farmland_110.jpg
# {'Expected': '<SOS> there are many different brown blocks in agricultural land .', 'Pruned_Predicted': 'many pieces of yellow farmlands are orderly together .', 'Unpruned_Predicted': 'many buildings and some bareland are in an industrial area .'}
# ✅ Saved results for farmland_110.jpg
# Processing Image 70: parking_381.jpg
# {'Expected': '<SOS> some white and red cars stop <UNK> in the parking .', 'Pruned_Predicted': 'many cars are parked in a parking lot near a building and several green trees .', 'Unpruned_Predicted': 'many cars are parked in a parking lot .'}
# ✅ Saved results for parking_381.jpg
# Processing Image 71: bridge_287.jpg
# {'Expected': '<SOS> a bridge is over a dark green river with some green trees on both sides .', 'Pruned_Predicted': 'a bridge is over a dark green river with many green trees on two sides of it .', 'Unpruned_Predicted': 'a bridge is on a river with several buildings on one side of it .'}
# ✅ Saved results for bridge_287.jpg
# Processing Image 72: commercial_315.jpg
# {'Expected': '<SOS> some commercial buildings and some green trees are around a crossroads .', 'Pruned_Predicted': 'many buildings and some green trees are in a commercial area .', 'Unpruned_Predicted': 'many buildings and some green trees are in a commercial area .'}
# ✅ Saved results for commercial_315.jpg
# Processing Image 73: river_256.jpg
# {'Expected': '<SOS> many green trees are located on two sides of a curved river khaki .', 'Pruned_Predicted': 'many green plants are found on both sides of a curved yellow river .', 'Unpruned_Predicted': 'many green trees are in two sides of a curved river .'}
# ✅ Saved results for river_256.jpg
# Processing Image 74: playground_264.jpg
# {'Expected': '<SOS> a football field is near some green trees and several buildings .', 'Pruned_Predicted': 'a football field is near some green trees and a building .', 'Unpruned_Predicted': 'a football field is near several buildings and some green trees .'}
# ✅ Saved results for playground_264.jpg
# Processing Image 75: resort_30.jpg
# {'Expected': '<SOS> there is a beach in front of the road .', 'Pruned_Predicted': 'several buildings with a swimming pool and some green trees are in a resort .', 'Unpruned_Predicted': 'a large building with a swimming pool and a tennis court is near a beach in a resort .'}
# ✅ Saved results for resort_30.jpg
# Processing Image 76: river_178.jpg
# {'Expected': '<SOS> many green trees and some farmland are located on two sides of a curved river .', 'Pruned_Predicted': 'many green plants and bare land are found on two sides of a curved river .', 'Unpruned_Predicted': 'many green trees and meadows are found on two sides of a curved river .'}
# ✅ Saved results for river_178.jpg
# Processing Image 77: school_209.jpg
# {'Expected': '<SOS> many buildings and some green trees are around a playground near a road in a school .', 'Pruned_Predicted': 'a playground is surrounded by many buildings .', 'Unpruned_Predicted': 'many buildings and some green trees are in a commercial area .'}
# ✅ Saved results for school_209.jpg
# Processing Image 78: square_264.jpg
# {'Expected': '<SOS> several rows of green trees are in a square .', 'Pruned_Predicted': 'many green trees and buildings are around a square .', 'Unpruned_Predicted': 'many green buildings and trees are in a dense residential area .'}
# ✅ Saved results for square_264.jpg
# Processing Image 79: baseballfield_206.jpg
# {'Expected': '<SOS> there is a road next to the baseball field .', 'Pruned_Predicted': 'a baseball field is surrounded by some green trees and many buildings .', 'Unpruned_Predicted': 'a playground is surrounded by some green trees and many buildings .'}
# ✅ Saved results for baseballfield_206.jpg
# Processing Image 80: airport_67.jpg
# {'Expected': '<SOS> many planes are parked in an airport .', 'Pruned_Predicted': 'many planes are parked at an airport .', 'Unpruned_Predicted': 'many planes are parked near several terminals in an airport with several parking lots .'}
# ✅ Saved results for airport_67.jpg
# Processing Image 81: denseresidential_126.jpg
# {'Expected': '<SOS> many green buildings and trees are located in a dense residential area .', 'Pruned_Predicted': 'many green buildings and trees are located in a dense residential area .', 'Unpruned_Predicted': 'many buildings and green trees are in a dense residential area .'}
# ✅ Saved results for denseresidential_126.jpg
# Processing Image 82: railwaystation_40.jpg
# {'Expected': '<SOS> the grey roofed house is a railway station .', 'Pruned_Predicted': 'many buildings are located on both sides of a railway station .', 'Unpruned_Predicted': 'many buildings and some green trees are in a commercial area .'}
# ✅ Saved results for railwaystation_40.jpg
# Processing Image 83: port_202.jpg
# {'Expected': '<SOS> it is a peaceful port with several boats stop here .', 'Pruned_Predicted': 'some boats are in a port near a dock .', 'Unpruned_Predicted': 'many boats are in a port near a dock .'}
# ✅ Saved results for port_202.jpg
# Processing Image 84: airport_282.jpg
# {'Expected': '<SOS> two planes are parked in an airport with two buildings .', 'Pruned_Predicted': 'some planes are parked near a terminal in an airport .', 'Unpruned_Predicted': 'many planes are parked near several terminals in an airport with several parking lots .'}
# ✅ Saved results for airport_282.jpg
# Processing Image 85: park_314.jpg
# {'Expected': '<SOS> two islands in the lake surrounded by green trees .', 'Pruned_Predicted': 'many buildings are around a park with many green trees and a pond .', 'Unpruned_Predicted': 'many buildings and green trees are in a dense residential area .'}
# ✅ Saved results for park_314.jpg
# Processing Image 86: industrial_250.jpg
# {'Expected': '<SOS> some rectangle buildings in different sizes are in an industrial area .', 'Pruned_Predicted': 'some buildings and green trees are in an industrial area .', 'Unpruned_Predicted': 'many buildings and some green trees are in an industrial area .'}
# ✅ Saved results for industrial_250.jpg
# Processing Image 87: mountain_246.jpg
# {'Expected': '<SOS> it is a piece of khaki mountain .', 'Pruned_Predicted': "it 's a piece of irregular khaki mountain .", 'Unpruned_Predicted': "it 's a piece of irregular khaki mountain ."}
# ✅ Saved results for mountain_246.jpg
# Processing Image 88: pond_227.jpg
# {'Expected': '<SOS> a rectangular pond is located in a factory with several storage tanks .', 'Pruned_Predicted': 'a road is near a rectangular pond .', 'Unpruned_Predicted': 'a football field is near several buildings and a road with several cars .'}
# ✅ Saved results for pond_227.jpg
# Processing Image 89: stadium_112.jpg
# {'Expected': '<SOS> many buildings are around a stadium .', 'Pruned_Predicted': 'a playground and a baseball field are surrounded by many buildings .', 'Unpruned_Predicted': 'many green trees and several buildings are around a playground with a football pitch in it .'}
# ✅ Saved results for stadium_112.jpg
# Processing Image 90: mediumresidential_110.jpg
# {'Expected': '<SOS> some trees and green buildings are located in an average residential area .', 'Pruned_Predicted': 'some buildings and many green trees are in a medium residential area .', 'Unpruned_Predicted': 'many green trees are around a building with a swimming pool .'}
# ✅ Saved results for mediumresidential_110.jpg
# Processing Image 91: railwaystation_96.jpg
# {'Expected': '<SOS> many green plants are in two sides of a railway station .', 'Pruned_Predicted': 'many green trees and some buildings are located on both sides of a train station .', 'Unpruned_Predicted': 'many buildings and some green trees are in a dense residential area .'}
# ✅ Saved results for railwaystation_96.jpg
# Processing Image 92: park_160.jpg
# {'Expected': '<SOS> railways are near a park with many green trees around a large pond .', 'Pruned_Predicted': 'many buildings and some green trees are around a park with a pond .', 'Unpruned_Predicted': 'many buildings and green trees are in a school with a playground and a baseball field .'}
# ✅ Saved results for park_160.jpg
# Processing Image 93: meadow_221.jpg
# {'Expected': "<SOS> it 's a piece of green lawn .", 'Pruned_Predicted': "it 's a piece of green lawn .", 'Unpruned_Predicted': 'a road is near a piece of green meadow .'}
# ✅ Saved results for meadow_221.jpg
# Processing Image 94: meadow_36.jpg
# {'Expected': '<SOS> next to the highway is a large ranch .', 'Pruned_Predicted': 'a road is near a piece of green meadow .', 'Unpruned_Predicted': "it 's a piece of green meadow ."}
# ✅ Saved results for meadow_36.jpg
# Processing Image 95: airport_268.jpg
# {'Expected': '<SOS> several planes are parked at an airport with several buildings .', 'Pruned_Predicted': 'many planes are in an airport near some buildings .', 'Unpruned_Predicted': 'many planes are parked near several terminals in an airport with several parking lots .'}
# ✅ Saved results for airport_268.jpg
# Processing Image 96: denseresidential_173.jpg
# {'Expected': '<SOS> many green buildings and trees are in a dense residential area .', 'Pruned_Predicted': 'many green buildings and trees are located in a dense residential area .', 'Unpruned_Predicted': 'many buildings and green trees are in a dense residential area .'}
# ✅ Saved results for denseresidential_173.jpg
# Processing Image 97: forest_62.jpg
# {'Expected': '<SOS> the area of the forest is very wide .', 'Pruned_Predicted': 'many green trees are in a forest .', 'Unpruned_Predicted': 'many green trees form a piece of green forest .'}
# ✅ Saved results for forest_62.jpg
# Processing Image 98: farmland_32.jpg
# {'Expected': '<SOS> a few crooked paths pass through the farm .', 'Pruned_Predicted': 'the small farm consists of grass and crops .', 'Unpruned_Predicted': 'many pieces of agricultural land are together .'}
# ✅ Saved results for farmland_32.jpg
# Processing Image 99: industrial_94.jpg
# {'Expected': '<SOS> many buildings are located in an industrial area .', 'Pruned_Predicted': 'many buildings are in an industrial area .', 'Unpruned_Predicted': 'many buildings and some green trees are in an industrial area .'}
# ✅ Saved results for industrial_94.jpg
# Processing Image 100: mountain_56.jpg
# {'Expected': '<SOS> the mountain is green and brown .', 'Pruned_Predicted': "it 's a piece of green mountain .", 'Unpruned_Predicted': 'many green trees form a piece of green forest .'}
# ✅ Saved results for mountain_56.jpg
# Processing Image 101: 00175.jpg
# {'Expected': '<SOS> an old court and many white cars surrounded .', 'Pruned_Predicted': 'a playground with basketball fields next to it is surrounded by some green trees and many buildings .', 'Unpruned_Predicted': 'many buildings and some green trees are around a playground .'}
# ✅ Saved results for 00175.jpg
# Processing Image 102: port_222.jpg
# {'Expected': '<SOS> this is a sea , many ships , road and trees .', 'Pruned_Predicted': 'many boats are in a port near a dock .', 'Unpruned_Predicted': 'many boats are ordered in a port near several green trees .'}
# ✅ Saved results for port_222.jpg
# Processing Image 103: school_8.jpg
# {'Expected': '<SOS> the stadium facilities are complete .', 'Pruned_Predicted': 'many buildings and green trees are in a school .', 'Unpruned_Predicted': 'many buildings and green trees are in a medium residential area .'}
# ✅ Saved results for school_8.jpg
# Processing Image 104: 00518.jpg
# {'Expected': '<SOS> many buildings and some green trees are around two playgrounds and a bare ground .', 'Pruned_Predicted': 'a playground is surrounded by many buildings .', 'Unpruned_Predicted': 'many buildings and some green trees are in an industrial area .'}
# ✅ Saved results for 00518.jpg
# Processing Image 105: bareland_236.jpg
# {'Expected': "<SOS> it 's a piece of yellow bare land .", 'Pruned_Predicted': "it 's a piece of yellow bare land .", 'Unpruned_Predicted': "it 's a piece of yellow desert ."}
# ✅ Saved results for bareland_236.jpg
# Processing Image 106: 00863.jpg
# {'Expected': '<SOS> two badminton fields and not far away from a crossroad .', 'Pruned_Predicted': 'a tennis court is surrounded by some buildings .', 'Unpruned_Predicted': 'many cars are parked in a parking lot with several green trees .'}
# ✅ Saved results for 00863.jpg
# Processing Image 107: mountain_118.jpg
# {'Expected': '<SOS> the ridges are lush and green .', 'Pruned_Predicted': 'many green trees are in a piece of forest .', 'Unpruned_Predicted': 'many green trees are in two sides of a curved river .'}
# ✅ Saved results for mountain_118.jpg
# Processing Image 108: industrial_340.jpg
# {'Expected': '<SOS> industrial houses on the street are well disposed .', 'Pruned_Predicted': 'many buildings are in an industrial area .', 'Unpruned_Predicted': 'many buildings and some green trees are in a school .'}
# ✅ Saved results for industrial_340.jpg
# Processing Image 109: school_172.jpg
# {'Expected': '<SOS> two playgrounds and several baseball fields are in a school .', 'Pruned_Predicted': 'many buildings and green trees are in a school with a playground and a baseball field .', 'Unpruned_Predicted': 'many buildings and some green trees are in a dense residential area .'}
# ✅ Saved results for school_172.jpg
# Processing Image 110: church_230.jpg
# {'Expected': '<SOS> many buildings and some green tree are in two sides of a church .', 'Pruned_Predicted': 'the houses in the residential area are very clean .', 'Unpruned_Predicted': 'many buildings and green trees are in a dense residential area .'}
# ✅ Saved results for church_230.jpg
# Processing Image 111: parking_216.jpg
# {'Expected': '<SOS> beside the road   there are two ploygon parking lots with several cars .', 'Pruned_Predicted': 'a lot of cars parked in the parking lot .', 'Unpruned_Predicted': 'many cars are parked in a parking lot with several small trees .'}
# ✅ Saved results for parking_216.jpg
# Processing Image 112: port_194.jpg
# {'Expected': '<SOS> many boats are in a large port near several buildings .', 'Pruned_Predicted': 'many boats are in a port near a building .', 'Unpruned_Predicted': 'many boats are ordered in a port near several green trees .'}
# ✅ Saved results for port_194.jpg
# Processing Image 113: pond_317.jpg
# {'Expected': '<SOS> many green trees and a road is near an irregular pond .', 'Pruned_Predicted': 'a pond with dark green water while with many spring green plants surrounded .', 'Unpruned_Predicted': 'many green trees are around an irregular pond .'}
# ✅ Saved results for pond_317.jpg
# Processing Image 114: baseballfield_167.jpg
# {'Expected': '<SOS> this is a grassland , several buildings and path .', 'Pruned_Predicted': 'a baseball field is surrounded by some buildings .', 'Unpruned_Predicted': 'a baseball field is near several buildings and some green trees .'}
# ✅ Saved results for baseballfield_167.jpg
# Processing Image 115: 00819.jpg
# {'Expected': '<SOS> a curved railway bridge over the straight highway bridge spans this broad river .', 'Pruned_Predicted': 'a bridge is on a river with many green trees on two sides of it .', 'Unpruned_Predicted': 'many green trees and several buildings are in a park with a pond .'}
# ✅ Saved results for 00819.jpg
# Processing Image 116: storagetanks_58.jpg
# {'Expected': '<SOS> many cars are parked beside the road .', 'Pruned_Predicted': 'some storage tanks are surrounded by some buildings .', 'Unpruned_Predicted': 'many cars are parked in a parking lot near several green trees .'}
# ✅ Saved results for storagetanks_58.jpg
# Processing Image 117: baseballfield_105.jpg
# {'Expected': '<SOS> a baseball field is surrounded by green trees .', 'Pruned_Predicted': 'a baseball field is surrounded by many green trees and buildings .', 'Unpruned_Predicted': 'a playground is surrounded by many green trees and buildings .'}
# ✅ Saved results for baseballfield_105.jpg
# Processing Image 118: beach_258.jpg
# {'Expected': '<SOS> yellow beach is between a piece of blue ocean and some green trees .', 'Pruned_Predicted': 'a large pond is surrounded by yellow green trees .', 'Unpruned_Predicted': 'a small wild road is in a piece of agricultural land .'}
# ✅ Saved results for beach_258.jpg
# Processing Image 119: pond_20.jpg
# {'Expected': '<SOS> many sparse green trees and bare land are around an irregular pond .', 'Pruned_Predicted': 'many green trees and some buildings are around a pond in a park near a road .', 'Unpruned_Predicted': 'many buildings and some green trees are in an industrial area .'}
# ✅ Saved results for pond_20.jpg
# Processing Image 120: church_138.jpg
# {'Expected': '<SOS> a church is close to three roads and some green trees .', 'Pruned_Predicted': 'a church is near a road with some green trees .', 'Unpruned_Predicted': 'many buildings and some green trees are in a commercial area .'}
# ✅ Saved results for church_138.jpg
# Processing Image 121: sparseresidential_2.jpg
# {'Expected': '<SOS> on agricultural land a house with a swimming pool is built on a square lawn near a road .', 'Pruned_Predicted': 'a building with a swimming pool is surrounded by several sparse green trees .', 'Unpruned_Predicted': 'many green trees are in two sides of a curved yellow river .'}
# ✅ Saved results for sparseresidential_2.jpg
# Processing Image 122: industrial_132.jpg
# {'Expected': '<SOS> many buildings are located in an industrial area .', 'Pruned_Predicted': 'many buildings are in an industrial area .', 'Unpruned_Predicted': 'many buildings and some bare land are located on both sides of a train station .'}
# ✅ Saved results for industrial_132.jpg
# Processing Image 123: railwaystation_134.jpg
# {'Expected': '<SOS> some buildings and some green trees are on two sides of a railway station .', 'Pruned_Predicted': 'some buildings and green trees are near a viaduct .', 'Unpruned_Predicted': 'many buildings and some green trees are in an industrial area .'}
# ✅ Saved results for railwaystation_134.jpg
# Processing Image 124: sparseresidential_257.jpg
# {'Expected': '<SOS> a forest surrounded by a house .', 'Pruned_Predicted': 'many green trees are around a building .', 'Unpruned_Predicted': 'many green trees are in a piece of forest .'}
# ✅ Saved results for sparseresidential_257.jpg
# Processing Image 125: church_55.jpg
# {'Expected': '<SOS> there are many grey roofed houses around the church .', 'Pruned_Predicted': 'a church is near a road with several cars .', 'Unpruned_Predicted': 'many buildings and green trees are in a dense residential area .'}
# ✅ Saved results for church_55.jpg
# Processing Image 126: commercial_60.jpg
# {'Expected': '<SOS> many trees were planted near the building .', 'Pruned_Predicted': 'many buildings are in a commercial area .', 'Unpruned_Predicted': 'many buildings and green trees are in a dense residential area .'}
# ✅ Saved results for commercial_60.jpg
# Processing Image 127: airport_319.jpg
# {'Expected': '<SOS> some planes are parked near a building in an airport with a parking lot .', 'Pruned_Predicted': 'several planes are parked near a terminal at an airport .', 'Unpruned_Predicted': 'many cars are parked in a parking lot near several buildings .'}
# ✅ Saved results for airport_319.jpg
# Processing Image 128: 00806.jpg
# {'Expected': '<SOS> a <UNK> white bridge and no car above it .', 'Pruned_Predicted': 'a bridge is on a river with many buildings on two sides .', 'Unpruned_Predicted': 'many buildings and some green trees are in a commercial area .'}
# ✅ Saved results for 00806.jpg
# Processing Image 129: 00887.jpg
# {'Expected': '<SOS> four baseball fields and a playground are surrounded by many green trees and several buildings .', 'Pruned_Predicted': 'a baseball field is surrounded by many buildings and some green trees .', 'Unpruned_Predicted': 'a building with swimming pool is surrounded by many scattered green trees and meadows .'}
# ✅ Saved results for 00887.jpg
# Processing Image 130: bridge_73.jpg
# {'Expected': '<SOS> many green trees are found on two sides of a river with a bridge over it .', 'Pruned_Predicted': 'a bridge is over a dark green river with many green trees on two sides of it .', 'Unpruned_Predicted': 'many green trees are in two sides of a river with a bridge over it .'}
# ✅ Saved results for bridge_73.jpg
# Processing Image 131: pond_408.jpg
# {'Expected': '<SOS> water in this pond is <UNK> while several trees stands sparsely by the bank .', 'Pruned_Predicted': 'a baseball field is surrounded by some green trees and several buildings .', 'Unpruned_Predicted': 'many green trees and several buildings with swimming pools are close to a beach in a resort .'}
# ✅ Saved results for pond_408.jpg
# Processing Image 132: stadium_156.jpg
# {'Expected': '<SOS> many green trees and two roads with many cars are around a white stadium .', 'Pruned_Predicted': 'some green trees and a parking lot are near a stadium .', 'Unpruned_Predicted': 'many cars are parked in a parking lot with several green trees .'}
# ✅ Saved results for stadium_156.jpg
# Processing Image 133: 00272.jpg
# {'Expected': '<SOS> a long bridge on a river with two baseball fields on one side .', 'Pruned_Predicted': 'a bridge is on a river with several pieces of meadows on two sides of it .', 'Unpruned_Predicted': 'a playground is surrounded by many green trees and several buildings .'}
# ✅ Saved results for 00272.jpg
# Processing Image 134: storagetanks_235.jpg
# {'Expected': '<SOS> several white stadium tanks are near many sparse green trees and several highways .', 'Pruned_Predicted': 'several storage tanks are near some green trees and a river .', 'Unpruned_Predicted': 'many green trees and several buildings with swimming pools are close to a beach in a resort .'}
# ✅ Saved results for storagetanks_235.jpg
# Processing Image 135: viaduct_38.jpg
# {'Expected': '<SOS> many cars are running on the overpass .', 'Pruned_Predicted': 'many green trees are near a viaduct .', 'Unpruned_Predicted': 'many buildings and some green trees are in a dense residential area .'}
# ✅ Saved results for viaduct_38.jpg
# Processing Image 136: 00423.jpg
# {'Expected': '<SOS> a playground is surrounded by some green plants and many buildings .', 'Pruned_Predicted': 'a playground with three basketball fields next to it is surrounded by many buildings .', 'Unpruned_Predicted': 'many buildings and some green trees are in a commercial area .'}
# ✅ Saved results for 00423.jpg
# Processing Image 137: 00659.jpg
# {'Expected': '<SOS> the main colour of the courts near the football field is orange , which is quite eye - <UNK> .', 'Pruned_Predicted': 'a playground is surrounded by some green trees and many buildings .', 'Unpruned_Predicted': 'many cars are parked in a parking lot with several green trees .'}
# ✅ Saved results for 00659.jpg
# Processing Image 138: industrial_21.jpg
# {'Expected': '<SOS> the factory with blue and green roofs is sandwiched between a river and a road .', 'Pruned_Predicted': 'many buildings and some green trees are in an industrial area .', 'Unpruned_Predicted': 'many buildings and some green trees are in a commercial area .'}
# ✅ Saved results for industrial_21.jpg
# Processing Image 139: storagetanks_51.jpg
# {'Expected': '<SOS> a row of houses were built in front of the storage tank .', 'Pruned_Predicted': 'some storage tanks are near a river .', 'Unpruned_Predicted': 'many storage tanks are near a river .'}
# ✅ Saved results for storagetanks_51.jpg
# Processing Image 140: 00532.jpg
# {'Expected': '<SOS> many buildings and several green trees are around a playground with three basketball fields in it .', 'Pruned_Predicted': 'a playground with three basketball fields in it is surrounded by many green trees and houses .', 'Unpruned_Predicted': 'many buildings and some green trees are in an industrial area .'}
# ✅ Saved results for 00532.jpg
# Processing Image 141: river_17.jpg
# {'Expected': '<SOS> many buildings are located on two sides of a river with three branches .', 'Pruned_Predicted': 'many buildings are located on two sides of a river with three branches .', 'Unpruned_Predicted': 'many buildings are around a park with many green trees and a pond .'}
# ✅ Saved results for river_17.jpg
# Processing Image 142: mountain_5.jpg
# {'Expected': '<SOS> many rivers cross the mountain .', 'Pruned_Predicted': "it 's a piece of green mountain .", 'Unpruned_Predicted': 'many green trees form a piece of green forest .'}
# ✅ Saved results for mountain_5.jpg
# Processing Image 143: commercial_83.jpg
# {'Expected': '<SOS> there are many buildings , dense distribution here , <UNK> road .', 'Pruned_Predicted': 'many buildings are in a commercial area .', 'Unpruned_Predicted': 'many buildings and some green trees are in a dense residential area .'}
# ✅ Saved results for commercial_83.jpg
# Processing Image 144: sparseresidential_259.jpg
# {'Expected': '<SOS> many green trees and meadows are around a building .', 'Pruned_Predicted': 'many green trees are around a building .', 'Unpruned_Predicted': 'a building with a swimming pool is surrounded by many green trees .'}
# ✅ Saved results for sparseresidential_259.jpg
# Processing Image 145: bareland_259.jpg
# {'Expected': "<SOS> it 's a piece of irregular khaki bareland .", 'Pruned_Predicted': "it 's a piece of bare land .", 'Unpruned_Predicted': "it 's a piece of yellow desert ."}
# ✅ Saved results for bareland_259.jpg
# Processing Image 146: commercial_89.jpg
# {'Expected': '<SOS> many tall buildings are in a commercial area .', 'Pruned_Predicted': 'many buildings are in a commercial area .', 'Unpruned_Predicted': 'many buildings and green trees are in a dense residential area .'}
# ✅ Saved results for commercial_89.jpg
# Processing Image 147: airport_277.jpg
# ...
# ✅ Saved results for industrial_32.jpg
# Processing Image 4494: 00664.jpg
# {'Expected': '<SOS> a large playground is next to a parking lot and several buildings .', 'Pruned_Predicted': 'a playground is surrounded by some green trees and several buildings .', 'Unpruned_Predicted': 'many cars are parked in a parking lot near several green trees .'}
# ✅ Saved results for 00664.jpg
# Processing Image 4495: playground_169.jpg
# {'Expected': '<SOS> some buildings and green trees are around a football pitch .', 'Pruned_Predicted': 'a playground is surrounded by some green trees and many buildings .', 'Unpruned_Predicted': 'a football field is near several buildings and some green trees .'}
# ✅ Saved results for playground_169.jpg
# Processing Image 4496: river_175.jpg
# {'Expected': '<SOS> many green trees are found on two sides of a curved river .', 'Pruned_Predicted': 'many green plants are found on both sides of a curved river .', 'Unpruned_Predicted': 'many green trees are in a piece of forest .'}
# ✅ Saved results for river_175.jpg
# Processing Image 4497: 00213.jpg
# {'Expected': '<SOS> several long buildings and some green plants are around four basketball fields .', 'Pruned_Predicted': 'a playground with basketball fields in it is surrounded by some trees and many houses .', 'Unpruned_Predicted': 'many buildings and some green trees are in an industrial area .'}
# ✅ Saved results for 00213.jpg
# Processing Image 4498: center_259.jpg
# {'Expected': '<SOS> some green trees and several buildings are around a white square center building .', 'Pruned_Predicted': 'a white building is surrounded by some green trees .', 'Unpruned_Predicted': 'many green trees are around a white oval building .'}
# ✅ Saved results for center_259.jpg
# Processing Image 4499: viaduct_389.jpg
# {'Expected': '<SOS> many lawns grow on both sides of the road .', 'Pruned_Predicted': 'many buildings with a parking lot and a square are near a viaduct .', 'Unpruned_Predicted': 'many buildings and some green trees are in an industrial area .'}
# ✅ Saved results for viaduct_389.jpg
# Processing Image 4500: pond_277.jpg
# {'Expected': '<SOS> green meadows are around an triangular pond .', 'Pruned_Predicted': 'a road is near a rectangular lake .', 'Unpruned_Predicted': 'many green trees are in two sides of a curved yellow river .'}
# ✅ Saved results for pond_277.jpg
# Processing Image 4501: viaduct_101.jpg
# {'Expected': '<SOS> there are many cars on the viaduct .', 'Pruned_Predicted': 'many green trees and buildings are near a viaduct .', 'Unpruned_Predicted': 'many green trees are near a viaduct with some cars .'}
# ✅ Saved results for viaduct_101.jpg
# Processing Image 4502: commercial_231.jpg
# {'Expected': '<SOS> many buildings and green trees are in a commercial area .', 'Pruned_Predicted': 'many green buildings and trees are located on both sides of a road in a commercial area .', 'Unpruned_Predicted': 'many buildings and some green trees are in a dense residential area .'}
# ✅ Saved results for commercial_231.jpg
# Processing Image 4503: beach_148.jpg
# {'Expected': '<SOS> white waves are in a piece of ocean .', 'Pruned_Predicted': 'white waves in the green ocean is near the yellow beach and green plants .', 'Unpruned_Predicted': 'many green trees and several buildings are around a silver grey circle building .'}
# ✅ Saved results for beach_148.jpg
# Processing Image 4504: school_27.jpg
# {'Expected': '<SOS> many buildings and some green plants are in a school .', 'Pruned_Predicted': 'many buildings and green trees are in a school .', 'Unpruned_Predicted': 'many buildings and some green trees are in a dense residential area .'}
# ✅ Saved results for school_27.jpg
# Processing Image 4505: square_78.jpg
# {'Expected': "<SOS> it 's a circular square .", 'Pruned_Predicted': 'many planes are around a long building .', 'Unpruned_Predicted': 'many buildings and some green trees are in a dense residential area .'}
# ✅ Saved results for square_78.jpg
# Processing Image 4506: mediumresidential_36.jpg
# {'Expected': '<SOS> many houses are surrounded by green plants .', 'Pruned_Predicted': 'some buildings and many green trees are in a medium residential area .', 'Unpruned_Predicted': 'many green trees are around a building with a swimming pool .'}
# ✅ Saved results for mediumresidential_36.jpg
# Processing Image 4507: commercial_36.jpg
# {'Expected': '<SOS> this area is the economic center of the city .', 'Pruned_Predicted': 'many buildings and some green trees are in a commercial area .', 'Unpruned_Predicted': 'many buildings and green trees are in a dense residential area .'}
# ✅ Saved results for commercial_36.jpg
# Processing Image 4508: square_188.jpg
# {'Expected': '<SOS> some green trees are in a square of circle .', 'Pruned_Predicted': 'some green trees are around a square square .', 'Unpruned_Predicted': 'many cars are parked in a parking lot with several green trees .'}
# ✅ Saved results for square_188.jpg
# Processing Image 4509: resort_42.jpg
# {'Expected': '<SOS> next to the beach is a vast resort .', 'Pruned_Predicted': 'many buildings with swimming pool and some green trees are in a school .', 'Unpruned_Predicted': 'many buildings and some green trees are in a school .'}
# ✅ Saved results for resort_42.jpg
# Processing Image 4510: desert_69.jpg
# {'Expected': '<SOS> the orange desert has a white pattern like the sea spray on it .', 'Pruned_Predicted': "it 's a big piece of yellow desert .", 'Unpruned_Predicted': "it 's a big piece of yellow desert ."}
# ✅ Saved results for desert_69.jpg
# Processing Image 4511: playground_96.jpg
# {'Expected': '<SOS> a playground is near a baseball field and two tennis courts .', 'Pruned_Predicted': 'a playground with a football field in it is surrounded by several buildings and green trees .', 'Unpruned_Predicted': 'a playground is surrounded by some green trees and many buildings .'}
# ✅ Saved results for playground_96.jpg
# Processing Image 4512: farmland_68.jpg
# {'Expected': '<SOS> many pieces of farmlands are together .', 'Pruned_Predicted': 'many pieces of farmlands are orderly together .', 'Unpruned_Predicted': 'many pieces of agricultural land are together .'}
# ✅ Saved results for farmland_68.jpg
# Processing Image 4513: port_8.jpg
# {'Expected': '<SOS> port resident house roof in red .', 'Pruned_Predicted': 'many boats are in a port near a dock .', 'Unpruned_Predicted': 'many buildings and some green trees are in a school .'}
# ✅ Saved results for port_8.jpg
# Processing Image 4514: stadium_183.jpg
# {'Expected': '<SOS> the football field   with a circular road and several empty parking lots around   has three stands on its sides .', 'Pruned_Predicted': 'some green trees are around a stadium .', 'Unpruned_Predicted': 'a large number of cars parked near the airport plains .'}
# ✅ Saved results for stadium_183.jpg
# Processing Image 4515: mountain_66.jpg
# {'Expected': '<SOS> many large trees are planted in the mountains .', 'Pruned_Predicted': "it 's a piece of green mountain .", 'Unpruned_Predicted': 'many green trees form a piece of forest .'}
# ✅ Saved results for mountain_66.jpg
# Processing Image 4516: bareland_216.jpg
# {'Expected': '<SOS> some green spots are scattered in a piece of naked khaki .', 'Pruned_Predicted': 'many small spots are scattered in a piece of khaki bareland .', 'Unpruned_Predicted': "it 's a piece of yellow desert ."}
# ✅ Saved results for bareland_216.jpg
# Processing Image 4517: desert_84.jpg
# {'Expected': '<SOS> no plants in the desert .', 'Pruned_Predicted': "it 's a big piece of yellow desert .", 'Unpruned_Predicted': "it 's a piece of yellow desert ."}
# ✅ Saved results for desert_84.jpg
# Processing Image 4518: forest_56.jpg
# {'Expected': '<SOS> the dark green forest is dense and hermetic .', 'Pruned_Predicted': 'a large number of trees have been planted on the land .', 'Unpruned_Predicted': 'many green trees are in a piece of forest .'}
# ✅ Saved results for forest_56.jpg
# Processing Image 4519: pond_4.jpg
# {'Expected': '<SOS> there is a pond in the middle of the land .', 'Pruned_Predicted': 'many green trees are around an irregular pond .', 'Unpruned_Predicted': 'many green trees are in two sides of a river with a bridge over it .'}
# ✅ Saved results for pond_4.jpg
# Processing Image 4520: 00647.jpg
# {'Expected': '<SOS> various of buildings embrace this rectangular playground .', 'Pruned_Predicted': 'a playground is surrounded by many green trees and many buildings .', 'Unpruned_Predicted': 'a playground is surrounded by many green trees and many buildings .'}
# ✅ Saved results for 00647.jpg
# Processing Image 4521: viaduct_108.jpg
# {'Expected': '<SOS> many green plants and bareland are close to a viaduct .', 'Pruned_Predicted': 'many green trees and some buildings are near a viaduct .', 'Unpruned_Predicted': 'many planes are parked near several terminals in an airport with several parking lots .'}
# ✅ Saved results for viaduct_108.jpg
# Processing Image 4522: mediumresidential_59.jpg
# {'Expected': '<SOS> two rows of buildings with some green plants are in two sides of a road .', 'Pruned_Predicted': 'some buildings and many green trees are in a medium residential area .', 'Unpruned_Predicted': 'many green trees are around a building with a swimming pool .'}
# ✅ Saved results for mediumresidential_59.jpg
# Processing Image 4523: viaduct_318.jpg
# {'Expected': '<SOS> many buildings and a large piece of meadow with several green trees are near a complicated viaduct .', 'Pruned_Predicted': 'many buildings and green meadows are near a complicated viaduct .', 'Unpruned_Predicted': 'many buildings and green trees are in a dense residential area .'}
# ✅ Saved results for viaduct_318.jpg
# Processing Image 4524: airport_17.jpg
# {'Expected': '<SOS> two planes are at an airport near a large parking lot .', 'Pruned_Predicted': 'some planes are parked near several buildings respectively at an airport .', 'Unpruned_Predicted': 'many planes are parked near two terminals in an airport with a parking lot .'}
# ✅ Saved results for airport_17.jpg
# Processing Image 4525: forest_139.jpg
# {'Expected': '<SOS> many green trees form a piece of forest .', 'Pruned_Predicted': 'many green trees are in a piece of forest .', 'Unpruned_Predicted': 'many green trees form a piece of green forest .'}
# ✅ Saved results for forest_139.jpg
# Processing Image 4526: resort_174.jpg
# {'Expected': '<SOS> many buildings and green trees are in a seaside resort with a pond .', 'Pruned_Predicted': 'many green trees and some buildings are in a park .', 'Unpruned_Predicted': 'many buildings and green trees are in a dense residential area .'}
# ✅ Saved results for resort_174.jpg
# Processing Image 4527: 00079.jpg
# {'Expected': '<SOS> many buildings around a playground are near to a road .', 'Pruned_Predicted': 'a playground with three basketball fields in it is surrounded by many trees and houses .', 'Unpruned_Predicted': 'many buildings and some green trees are in an industrial area .'}
# ✅ Saved results for 00079.jpg
# Processing Image 4528: 00058.jpg
# {'Expected': '<SOS> the building is encircled by the lush plants .', 'Pruned_Predicted': 'a playground is surrounded by many green trees and buildings .', 'Unpruned_Predicted': 'many planes are parked near several terminals in an airport with a parking lot .'}
# ✅ Saved results for 00058.jpg
# Processing Image 4529: parking_314.jpg
# {'Expected': '<SOS> all kinds of cars .', 'Pruned_Predicted': 'many cars are in a parking lot near a building .', 'Unpruned_Predicted': 'many cars are parked in a parking lot near several buildings .'}
# ✅ Saved results for parking_314.jpg
# Processing Image 4530: 00840.jpg
# {'Expected': '<SOS> a basketball field and a tennis court are surrounded by several buildings .', 'Pruned_Predicted': 'a tennis court is surrounded by several buildings and two rows of green trees .', 'Unpruned_Predicted': 'a large number of cars parked near the airport plains .'}
# ✅ Saved results for 00840.jpg
# Processing Image 4531: farmland_24.jpg
# {'Expected': '<SOS> many pieces of green farmland are together .', 'Pruned_Predicted': 'many pieces of farmlands are near a viaduct .', 'Unpruned_Predicted': 'many pieces of agricultural land are together .'}
# ✅ Saved results for farmland_24.jpg
# Processing Image 4532: pond_256.jpg
# {'Expected': '<SOS> many green trees are around a polygonal pond .', 'Pruned_Predicted': 'many green trees and meadows are around a pond .', 'Unpruned_Predicted': 'many green trees are around an irregular pond .'}
# ✅ Saved results for pond_256.jpg
# Processing Image 4533: beach_100.jpg
# {'Expected': '<SOS> some white waves in an ocean are near a beach .', 'Pruned_Predicted': 'white waves in the green ocean is near the yellow beach and green plants .', 'Unpruned_Predicted': 'white waves in an ocean are near a beach .'}
# ✅ Saved results for beach_100.jpg
# Processing Image 4534: pond_216.jpg
# {'Expected': '<SOS> an almost rectangular green pond is near a small wild road .', 'Pruned_Predicted': 'a pond is near a road with green trees in two sides .', 'Unpruned_Predicted': 'a bridge is on a river with some green trees and bare land .'}
# ✅ Saved results for pond_216.jpg
# Processing Image 4535: storagetanks_201.jpg
# {'Expected': '<SOS> the <UNK> white columnar tank is connected to the four small white columnar tanks by pipes .', 'Pruned_Predicted': 'several storage tanks are near a river .', 'Unpruned_Predicted': 'many buildings and some green trees are in a school .'}
# ✅ Saved results for storagetanks_201.jpg
# Processing Image 4536: 00164.jpg
# {'Expected': '<SOS> a playground is surrounded by some green trees and buildings .', 'Pruned_Predicted': 'a playground with basketball fields next to it is surrounded by some green trees and many buildings .', 'Unpruned_Predicted': 'a playground with two basketball fields in it is surrounded by many green trees and many buildings .'}
# ✅ Saved results for 00164.jpg
# Processing Image 4537: 00876.jpg
# {'Expected': '<SOS> several highways and railways make the traffic convenient .', 'Pruned_Predicted': 'a bridge is on a river with many buildings on one side .', 'Unpruned_Predicted': 'many buildings and green trees are in a medium residential area .'}
# ✅ Saved results for 00876.jpg
# Processing Image 4538: denseresidential_39.jpg
# {'Expected': '<SOS> many green trees are planted around the neighborhood .', 'Pruned_Predicted': 'many buildings and green trees are in a dense residential area .', 'Unpruned_Predicted': 'many green buildings and trees are located in a dense residential area .'}
# ✅ Saved results for denseresidential_39.jpg
# Processing Image 4539: 00170.jpg
# {'Expected': '<SOS> two tennis courts are next to a piece of bare ground .', 'Pruned_Predicted': 'two tennis courts are next to a road .', 'Unpruned_Predicted': 'a playground with two basketball fields next to it is surrounded by some green trees and many buildings .'}
# ✅ Saved results for 00170.jpg
# Processing Image 4540: beach_144.jpg
# {'Expected': '<SOS> a line of white waves is between a beach and an ocean .', 'Pruned_Predicted': 'a white plane is on the runway .', 'Unpruned_Predicted': 'white waves in an ocean are near a beach .'}
# ✅ Saved results for beach_144.jpg
# Processing Image 4541: school_91.jpg
# {'Expected': '<SOS> many buildings and green plants are in a school .', 'Pruned_Predicted': 'many buildings and some green trees are in an industrial area .', 'Unpruned_Predicted': 'many buildings and some green trees are in a dense residential area .'}
# ✅ Saved results for school_91.jpg
# Processing Image 4542: square_309.jpg
# {'Expected': '<SOS> round the square is surrounded by rows of houses .', 'Pruned_Predicted': 'a square is between two parallel roads .', 'Unpruned_Predicted': 'many cars are parked in a parking lot with several small trees .'}
# ✅ Saved results for square_309.jpg
# Processing Image 4543: commercial_77.jpg
# {'Expected': '<SOS> many buildings and some green trees are in a commercial area .', 'Pruned_Predicted': 'many buildings are in a commercial area .', 'Unpruned_Predicted': 'many buildings and green trees are in a dense residential area .'}
# ✅ Saved results for commercial_77.jpg
# ✅ All results saved successfully in logs folder!

# %% [markdown]
# # Calculate Metric Score

# %%
with open("results.json", "r") as file:
    data = json.load(file)  # Convert JSON to Python dictionary

# %%
expected = data["expected"]
predicted = data["predicted"]

# %%
scorer = rouge.Rouge()
cider_scorer = cider.Cider()
bleu_scorer = bleu.Bleu(4)
ciders = 0

# %%
gts = {}
res = {}
met = 0

for idx, (ref, pred) in enumerate(zip(expected, predicted)):
    if isinstance(ref, str):
        ref = [ref]
    if isinstance(pred, str):
        pred = [pred]

    # Sanity check
    assert(type(ref) is list)
    assert(len(ref) > 0)
    assert(type(pred) is list)
    assert(len(pred) == 1)

    # Fill the gts and res dictionaries for CIDEr scoring
    gts[idx] = ref
    res[idx] = pred
    met += meteor_score([word_tokenize(ref[0].replace("<SOS" , ""))], word_tokenize(pred[0]))

# %%
cider_score, cider_scores = cider_scorer.compute_score(gts, res)
rougeL, rouge_scores = scorer.compute_score(gts, res)
bleu_score, bleu_scores = bleu_scorer.compute_score(gts, res)
# Out:
# {'testlen': 52343, 'reflen': 58475, 'guess': [52343, 47800, 43257, 38714], 'correct': [26786, 12228, 7146, 4460]}
# ratio: 0.8951346729371373

# %%
print("ROUGE-L = ", rougeL)
print("Cider = ", ciders)
print("Bleu = ", bleu_score)
# Out:
# ROUGE-L =  0.43039683333350276
# Cider =  1.7229689709756495
# Bleu =  [0.4551677779184838, 0.3218182357591058, 0.24780879933616404, 0.19871690288396454]

# %%
print("Meteor = ", met/len(expected))
# Out:
# Meteor =  0.39987502808888814

# %% [markdown]
# #
